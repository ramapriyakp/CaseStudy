# %% [markdown]
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# Medic<span class="_ _0"></span>al In<span class="_ _1"></span>v<span
# class="_ _0"></span>en<span class="_ _0"></span>t<span
# class="_ _0"></span>ory Op<span class="_ _0"></span>timisa<span
# class="_ _0"></span>tion
#
# •<span class="ff1 ls2 ws0">Pr<span class="_ _1"></span>ojec<span
# class="_ _2"></span>t Miles<span class="_ _0"></span>tones</span>
#
# •<span class="ff1 ls2 ws0">Pr<span class="_ _0"></span>epar<span
# class="_ _0"></span>ed by Ramapriy<span class="_ _1"></span>a K P
# </span>
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# Contents
#
# ●<span class="ff5 ls2 ws0">Business Objective</span>
#
# ●<span class="ff5 ls2 ws0">Business Constraints</span>
#
# ●<span class="ff5 ls2 ws0">Project <span
# class="_ _3"></span>Architecture</span>
#
# ●<span class="ff5 ls2 ws0">Data Collection</span>
#
# ●<span class="ff5 ls2 ws0">Exploratory <span class="_ _0"></span>Data
# <span class="_ _3"></span>Analysis</span>
#
# ●<span class="ff5 ls2 ws0">Data <span class="_ _1"></span>V<span
# class="_ _3"></span>isua<span class="_ _2"></span>lization</span>
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# Business<span class="_"> </span>Pr<span class="_ _1"></span>oblem
#
# Bounce rate is increasi<span class="_ _0"></span>ng <span
# class="_ _2"></span>significan<span class="_ _0"></span>tly <span
# class="_ _2"></span>leading to patient dissatisfaction<span
# class="_ _0"></span>.
#
# ●<span class="ff6 ls2 ws0">Business Objective : Minimize<span
# class="_ _0"></span> <span class="_ _2"></span>bounce rate.</span>
#
# ●<span class="ff6 ls2 ws0">Business Constrain<span class="_ _0"></span>t
# <span class="_ _2"></span>: Minimize inventory<span class="_ _0"></span>
# <span class="_ _2"></span>cost.</span>
#
# Success Criteria:
#
# o Business Success Criteria<span class="_ _0"></span> <span
# class="_ _2"></span>: Reduce boun<span class="_ _0"></span>ce rate by at
# least 30%.
#
# o Economic Success Criteria<span class="_ _0"></span> <span
# class="_ _2"></span>: Increase revenu<span class="_ _0"></span>e <span
# class="_ _2"></span>by at least 20 lacs INR by<span class="_ _0"></span>
# reducing bounce
#
# rate
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# Pr<span class="_ _1"></span>ojec<span class="_ _2"></span>t <span
# class="_ _0"></span>Overview and <span class="_ _0"></span>Scope
#
# Purpose <span class="ff6">: Streamline, automate, an<span
# class="_ _0"></span>d optimize medical inventory<span
# class="_ _0"></span> <span class="_ _2"></span>management to improve
# </span>
#
# care & ef<span class="_ _0"></span>ficiency<span class="_ _4"></span>.
#
# Objectiv<span class="_ _0"></span>es<span class="ff6 ws0">: Reduce
# stockouts/overstock, cut costs<span class="_ _2"></span>, improve
# forecasting, automate tasks, </span>
#
# and boost satisfaction.
#
# Expected Benefits <span class="ff6">:Cost saving<span
# class="_ _0"></span>s, <span class="_ _2"></span>reduced w<span
# class="_ _0"></span>aste, <span class="_ _2"></span>better patient care,
# increa<span class="_ _0"></span>sed </span>
#
# operation<span class="_ _0"></span>al <span class="_ _2"></span>ef<span
# class="_ _0"></span>ficiency<span class="_ _4"></span>.
#
# Success<span class="_ _0"></span> <span class="_ _2"></span>Criteria
# <span class="ff6">: De<span class="_ _0"></span>crease
# costs/shortage<span class="_ _0"></span>s, <span
# class="_ _2"></span>improve<span class="_ _0"></span> <span
# class="_ _2"></span>forecastin<span class="_ _0"></span>g and
# inventory<span class="_ _0"></span> <span
# class="_ _2"></span>turnover<span class="_ _5"></span>, </span>
#
# achieve measura<span class="_ _0"></span>ble <span
# class="_ _2"></span>KPIs.
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# Pr<span class="_ _1"></span>oje<span class="_ _2"></span>ct <span
# class="_ _3"></span>Ar<span class="_ _1"></span>chitect<span
# class="_ _2"></span>ur<span class="_ _1"></span>e
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# Data Dictionary
#
# VARIA<span class="_ _0"></span>BLE <span class="_ _2"></span>NAME<span
# class="_ _6"> </span>VARIA<span class="_ _0"></span>BLE <span
# class="_ _2"></span>DESCRIPTION<span class="_ _7"> </span>Data ty<span
# class="_ _0"></span>pe<span class="_ _8"> </span>Range<span
# class="_ _9"> </span>Scale of Measurement<span class="_ _a">
# </span>Relevant/
#
# Irrelevant
#
# T<span class="_ _0"></span>ypeofsales<span class="_ _b"> </span>T<span
# class="_ _0"></span>ype <span class="_ _0"></span>of sale of the drug.
# Either the drug<span class="_ _0"></span> is sold
#
# or returned.
#
# String<span class="_ _c"> </span>Return, Sale<span class="_ _d">
# </span>count<span class="_ _e"> </span>relevant
#
# Patient_ID<span class="_ _f"> </span>ID of a patient<span class="_ _10">
# </span>integer<span class="_ _11"> </span>12017998218<span
# class="_ _0"></span> to
#
# 12018125353
#
# count<span class="_ _e"> </span>relevant
#
# Specialisation<span class="_ _12"> </span>Name of Specialisation <span
# class="_ _0"></span>(eg. Cardiology<span class="_ _0"></span>)<span
# class="_ _13"> </span>String<span class="_ _c"> </span>Specialisation1
# <span class="_ _0"></span>to
#
# Specialisation75
#
# count<span class="_ _e"> </span>relevant
#
# Dept<span class="_ _14"> </span>Pharmacy<span class="_ _1"></span>, the
# <span class="_ _0"></span>fo<span class="_ _2"></span>rmulation <span
# class="_ _0"></span>is related w<span class="_ _0"></span>ith.<span
# class="_ _15"> </span>String<span class="_ _c"> </span>Department1,
#
# Department2,
#
# Department3
#
# count<span class="_ _e"> </span>relevant
#
# Dateofbill<span class="_ _16"> </span>Date of purchase <span
# class="_ _0"></span>of medicine<span class="_ _17"> </span>date<span
# class="_ _18"> </span>01/01/2022 <span class="_ _0"></span>to
# 09/30/2022<span class="_ _19"> </span>days<span class="_ _1a">
# </span>relevant
#
# Quantity<span class="_ _1b"> </span>Quantity of the drug<span
# class="_ _1c"> </span>integer<span class="_ _11"> </span>0 to 150<span
# class="_ _1d"> </span>count<span class="_ _e"> </span>relevant
#
# ReturnQuantit
#
# y
#
# Quantity of drug returned by <span class="_ _0"></span>patient to the
#
# pharmacy
#
# integer<span class="_ _11"> </span>0 to 50<span class="_ _1e">
# </span>count<span class="_ _e"> </span>relevant
#
# Final_Cost<span class="_ _1f"> </span>Final Cost of the drug <span
# class="_ _0"></span>(Quantity included)<span class="_ _15">
# </span>float<span class="_ _20"> </span>40 to 33178<span class="_ _21">
# </span>rupee<span class="_ _22"> </span>relevant
#
# Final_Sales<span class="_ _23"> </span>Final sales of drug<span
# class="_ _24"> </span>float<span class="_ _20"> </span>0 to 39490<span
# class="_ _25"> </span>rupee<span class="_ _22"> </span>relevant
#
# RtnMRP<span class="_ _a"> </span>MRP<span class="_ _0"></span> of
# returned drug <span class="_ _0"></span>(Quantity <span
# class="_ _0"></span>included)<span class="_ _26"> </span>float<span
# class="_ _20"> </span>0 to 8041<span class="_ _27"> </span>rupee<span
# class="_ _22"> </span>relevant
#
# Formulation<span class="_ _28"> </span>T<span class="_ _0"></span>ype
# <span class="_ _0"></span>of fo<span class="_ _2"></span>rmulation<span
# class="_ _29"> </span>String<span class="_ _c">
# </span>Form1,Form2,Fo<span class="_ _2"></span>rm3,paten
#
# t
#
# count<span class="_ _e"> </span>relevant
#
# DrugName<span class="_ _2a"> </span>Generic name <span
# class="_ _0"></span>of<span class="_ _2"></span> the drug<span
# class="_ _2b"> </span>String<span class="_ _c"> </span>753 unique <span
# class="_ _0"></span>elements<span class="_ _2c"> </span>count<span
# class="_ _e"> </span>relevant
#
# SubCat<span class="_ _2d"> </span>Subcategory <span
# class="_ _0"></span>(T<span class="_ _0"></span>ype) to the
# category<span class="_ _0"></span> of drugs.<span class="_ _2e">
# </span>String<span class="_ _c"> </span>18 unique elements<span
# class="_ _2f"> </span>count<span class="_ _e"> </span>relevant
#
# SubCat1<span class="_ _30"> </span>Subcategory <span
# class="_ _0"></span>(condition) to the category<span
# class="_ _0"></span> of<span class="_ _2"></span>
#
# drugs
#
# String<span class="_ _c"> </span>21 unique elements<span class="_ _2f">
# </span>count<span class="_ _e"> </span>relevant
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# Exploratory <span class="_ _0"></span>Data <span
# class="_ _3"></span>Analysis \[EDA\]
#
# Statistical <span class="_ _0"></span>Insights<span class="_ _31">
# </span><span class="v1">Business <span
# class="_ _0"></span>Insights</span>
#
# •<span class="ff6 ls2 ws0">Several <span class="_ _0"></span>features
# <span class="_ _0"></span>exhibit means <span class="_ _0"></span>much
# higher </span>
#
# than <span class="_ _0"></span>their medians, <span
# class="_ _1"></span>reflect<span class="_ _2"></span>ing <span
# class="_ _1"></span>right (positiv<span class="_ _0"></span>e)
#
# skewness <span class="_ _0"></span>due to <span class="_ _0"></span>the
# presence <span class="_ _0"></span>of high
#
# outliers.
#
# •<span class="ff6 ls2 ws0">Statistical <span class="_ _0"></span>spread
# in <span class="_ _0"></span>several charts <span
# class="_ _0"></span>suggests </span>
#
# most <span class="_ _0"></span>values cluster <span
# class="_ _0"></span>tightly around <span class="_ _1"></span>the mean,
#
# but significant <span class="_ _0"></span>outliers <span
# class="_ _0"></span>exist that <span class="_ _0"></span>stretch <span
# class="_ _0"></span>the
#
# range.
#
# •<span class="ff6 ls2 ws0">The <span class="_ _0"></span>most
# frequen<span class="_ _0"></span>t <span class="_ _0"></span>types of
# sales, </span>
#
# specialisations, <span class="_ _1"></span>and departments <span
# class="_ _0"></span>are
#
# identified <span class="_ _0"></span>by their <span
# class="_ _0"></span>modes, <span class="_ _0"></span>with "Sale,"
#
# "Specialisation4," <span class="_ _0"></span>and <span
# class="_ _0"></span>"Department1" <span class="_ _0"></span>being
#
# the most <span class="_ _0"></span>common, <span
# class="_ _0"></span>respectively<span class="_ _32"></span>.
#
# •<span class="ff6 ls2 ws0">inventory<span class="_ _0"></span> and
# financial <span class="_ _0"></span>data <span class="_ _0"></span>show
# strong </span>
#
# positive <span class="_ _0"></span>skew<span class="_ _1"></span>, with
# <span class="_ _0"></span>most values being <span
# class="_ _1"></span>s<span class="_ _2"></span>mall
#
# but a <span class="_ _0"></span>few rare <span class="_ _0"></span>and
# v<span class="_ _0"></span>ery large <span class="_ _0"></span>events
#
# significantly <span class="_ _0"></span>affecting <span
# class="_ _1"></span>totals and <span class="_ _0"></span>averages. <span
# class="_ _1"></span>T
#
# •<span class="ff6 ls2 ws0">The <span class="_ _0"></span>mode analy<span
# class="_ _0"></span>sis shows "Specialisation4" <span
# class="_ _1"></span>, </span>
#
# "Department1" <span class="_ _1"></span>, "SODIUM CHLORIDE IVF<span
# class="_ _0"></span>
#
# 100ML" <span class="_ _0"></span>as the m<span class="_ _0"></span>ost
# frequently <span class="_ _0"></span>v<span
# class="_ _0"></span>alues.T<span class="_ _4"></span>argeted
#
# forecasting <span class="_ _0"></span>and <span
# class="_ _0"></span>stock<span class="_ _2"></span> <span
# class="_ _0"></span>optimization <span class="_ _1"></span>f<span
# class="_ _2"></span>or these <span class="_ _0"></span>areas
#
# will yield the <span class="_ _0"></span>greatest <span
# class="_ _0"></span>efficiency<span class="_ _0"></span> gains.
#
# •<span class="ff6 ls2 ws0">Quantity<span class="_ _32"></span>,<span
# class="_ _2"></span> <span class="_ _0"></span>ReturnQuantity<span
# class="_ _32"></span>, Final_Sales <span class="_ _0"></span>hav<span
# class="_ _0"></span>e </span>
#
# compressed<span class="_ _0"></span> interqua<span
# class="_ _0"></span>rtile <span class="_ _0"></span>ranges <span
# class="_ _0"></span>(IQR) <span class="_ _0"></span>at the <span
# class="_ _0"></span>low
#
# end w<span class="_ _0"></span>ith the bulk <span class="_ _0"></span>of
# activity<span class="_ _0"></span> being small-sized
#
# orders <span class="_ _0"></span>or returns. <span class="_ _0"></span>
# <span class="_ _1"></span>Automation <span class="_ _0"></span>and <span
# class="_ _0"></span>process
#
# optimization <span class="_ _0"></span>should <span
# class="_ _0"></span>target <span class="_ _0"></span>this “core” <span
# class="_ _0"></span>activity<span class="_ _0"></span> band.
#
# •<span class="ff6 ls2 ws0">bounce <span class="_ _0"></span>rate of
# <span class="_ _0"></span> 22.17%, show<span class="_ _0"></span>s that
# a </span>
#
# considerable <span class="_ _0"></span>proportion <span
# class="_ _1"></span>of supply requests <span class="_ _1"></span>are not
#
# being fulfilled, <span class="_ _0"></span>w<span
# class="_ _0"></span>hich may be driv<span class="_ _0"></span>ing
# away<span class="_ _0"></span> demand
#
# or im<span class="_ _0"></span>pacting serv<span class="_ _0"></span>ice
# quality<span class="_ _4"></span>.
#
# •<span class="ff6 ls2 ws0">top-selling <span class="_ _0"></span>items
# are <span class="_ _0"></span>basic <span
# class="_ _0"></span>necess<span class="_ _2"></span>ities <span
# class="_ _1"></span>(s<span class="_ _2"></span>odium </span>
#
# chloride <span class="_ _0"></span>solutions, ondanse<span
# class="_ _0"></span>tron, <span class="_ _0"></span>IV fluids, <span
# class="_ _0"></span>water <span class="_ _0"></span>for
#
# injection), <span class="_ _0"></span>indicating <span
# class="_ _0"></span>these are <span class="_ _0"></span>essential <span
# class="_ _0"></span>inventory<span class="_ _0"></span>
#
# items.
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# Data Pr<span class="_ _1"></span>epr<span class="_ _0"></span>ocessing
#
# Dat<span class="_ _0"></span>a Collection: sec<span
# class="_ _0"></span>ondary dat<span class="_ _0"></span>a sources w<span
# class="_ _0"></span>as used f<span class="_ _0"></span>or analy<span
# class="_ _0"></span>sis
#
# Dat<span class="_ _0"></span>a Cleaning <span class="_ _0"></span>: Some
# of the c<span class="_ _0"></span>at<span
# class="_ _0"></span>egoric<span class="_ _0"></span>al columns had
# null<span class="_ _0"></span>s and wer<span class="_ _0"></span>e
# r<span class="_ _0"></span>eplaced wi<span class="_ _0"></span>th most
# fr<span class="_ _0"></span>equen<span class="_ _0"></span>t value.
#
# Dat<span class="_ _0"></span>a T<span class="_ _32"></span>rans<span
# class="_ _0"></span>f<span class="_ _0"></span>orma<span
# class="_ _0"></span>tion : Dat<span class="_ _0"></span>eofbill column
# <span class="_ _0"></span>was con<span class="_ _0"></span>v<span
# class="_ _0"></span>ert<span class="_ _0"></span>ed int<span
# class="_ _0"></span>o da<span class="_ _0"></span>te type
#
# Ag<span class="_ _2"></span>greg<span class="_ _1"></span>ation: <span
# class="_ _0"></span> dat<span class="_ _0"></span>a summariz<span
# class="_ _1"></span>ed <span class="_ _2"></span> a<span
# class="_ _0"></span>t <span class="_ _2"></span>mon<span
# class="_ _0"></span>thly<span class="_ _32"></span>, departmen<span
# class="_ _0"></span>t<span class="_ _2"></span>-wise, specializ<span
# class="_ _0"></span>a<span class="_ _0"></span>tion <span
# class="_ _2"></span>lev<span class="_ _0"></span>els.
#
# Outlier Handling : Da<span class="_ _0"></span>ta within <span
# class="_ _0"></span>(5,95)<span class="_ _2"></span> <span
# class="_ _0"></span>percen<span class="_ _0"></span>tile was
# consider<span class="_ _0"></span>ed t<span class="_ _0"></span>o r<span
# class="_ _0"></span>emov<span class="_ _0"></span>e oulier impact.
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# Data <span class="_ _1"></span>V<span class="_ _5"></span>isualization
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# Data <span class="_ _1"></span>V<span class="_ _5"></span>isualization
#
# •<span class="ff1 ls2 ws0">bounce r<span class="_ _0"></span>a<span
# class="_ _0"></span>te is 22.17% <span class="_ _0"></span>and
# fluctua<span class="_ _0"></span>tes thr<span
# class="_ _0"></span>oughout the y<span class="_ _0"></span>ear<span
# class="_ _4"></span>, indica<span class="_ _0"></span>ting r<span
# class="_ _0"></span>equests ar<span class="_ _0"></span>e </span>
#
# not being fulfil<span class="_ _0"></span>led, especially peaking
# tow<span class="_ _0"></span>ar<span class="_ _0"></span>ds the end of
# the y<span class="_ _0"></span>ear<span class="_ _3"></span>.
#
# •<span class="ff9 ls2 ws0">Department1 i<span class="_ _0"></span>s
# responsible f<span class="_ _0"></span>or the v<span
# class="_ _0"></span>as<span class="_ _0"></span>t majority of sales
# (\~₹1.5M) but als<span class="_ _0"></span>o faces the </span>
#
# highes<span class="_ _0"></span>t st<span class="_ _0"></span>ock<span
# class="_ _1"></span>out r<span class="_ _0"></span>at<span
# class="_ _0"></span>e (\>20%), putting <span
# class="_ _0"></span>oper<span class="_ _0"></span>ations and r<span
# class="_ _0"></span>ev<span class="_ _0"></span>enue a<span
# class="_ _0"></span>t major risk.
#
# •<span class="ff1 ls2 ws0">bulk of in<span class="_ _0"></span>v<span
# class="_ _0"></span>ent<span class="_ _0"></span>ory mov<span
# class="_ _0"></span>emen<span class="_ _0"></span>t is limited t<span
# class="_ _0"></span>o a f<span class="_ _0"></span>ew ess<span
# class="_ _0"></span>ential<span class="_ _0"></span> <span
# class="_ _2"></span>drug<span class="_ _2"></span>s lik<span
# class="_ _1"></span>e Sodium Chloride </span>
#
# and Ondansetr<span class="_ _0"></span>on, em<span
# class="_ _0"></span>phasizing the risk of st<span
# class="_ _0"></span>ock<span class="_ _1"></span>outs for <span
# class="_ _0"></span>these cor<span class="_ _0"></span>e pr<span
# class="_ _0"></span>oducts.
#
# •<span class="ff1 ls2 ws0">Sales are hea<span class="_ _0"></span>vily
# concen<span class="_ _0"></span>tr<span class="_ _0"></span>a<span
# class="_ _0"></span>ted in Specialisa<span class="_ _0"></span>tion4,
# with much low<span class="_ _0"></span>er con<span
# class="_ _0"></span>tributions fr<span class="_ _0"></span>om </span>
#
# other<span class="_ _0"></span>s, indica<span class="_ _0"></span>ting a
# r<span class="_ _0"></span>eliance on a narr<span class="_ _1"></span>ow
# segmen<span class="_ _0"></span>t of medical<span class="_ _0"></span>
# specialties.
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# Data <span class="_ _1"></span>V<span class="_ _5"></span>isualization
#
# •<span class="ff1 ls2 ws0">For <span class="_ _0"></span>Each indiv<span
# class="_ _0"></span>idual f<span class="_ _0"></span>ea<span
# class="_ _0"></span>tures the his<span class="_ _0"></span>togr<span
# class="_ _0"></span>am and bo<span class="_ _0"></span>x <span
# class="_ _0"></span>plots are plot<span class="_ _0"></span>t<span
# class="_ _0"></span>ed. Foll<span class="_ _0"></span>owing ar<span
# class="_ _0"></span>e </span>
#
# the k<span class="_ _0"></span>e<span class="_ _0"></span>y t<span
# class="_ _0"></span>ak<span class="_ _0"></span>eaw<span
# class="_ _0"></span>a<span class="_ _0"></span>y<span
# class="_ _0"></span>s
#
# •<span class="ff1 ls2 ws0">Mos<span class="_ _0"></span>t numeric
# variables<span class="_ _0"></span> <span class="_ _2"></span>ar<span
# class="_ _0"></span>e highly righ<span class="_ _0"></span>t-sk<span
# class="_ _0"></span>ew<span class="_ _0"></span>ed, with e<span
# class="_ _0"></span>xtr<span class="_ _0"></span>eme outliers pulling
# the </span>
#
# mean abov<span class="_ _0"></span>e the median. This suggests <span
# class="_ _0"></span>the presence of <span class="_ _0"></span>r<span
# class="_ _0"></span>are but high-impact
#
# tr<span class="_ _0"></span>ansactions.
#
# •<span class="ff1 ls2 ws0">Mos<span class="_ _0"></span>t cat<span
# class="_ _0"></span>egori<span class="_ _0"></span>cal v<span
# class="_ _0"></span>ariables (e.g., T<span
# class="_ _5"></span>ypeofsales<span class="_ _0"></span>,
# Specialisatio<span class="_ _0"></span>n, <span
# class="_ _2"></span>Dept) ar<span class="_ _0"></span>e domina<span
# class="_ _0"></span>ted by <span class="_ _0"></span>a </span>
#
# single ca<span class="_ _0"></span>teg<span class="_ _0"></span>ory .
# This could <span class="_ _0"></span>indica<span class="_ _0"></span>te
# imbalanced da<span class="_ _0"></span>ta or a na<span
# class="_ _0"></span>tur<span class="_ _0"></span>al dominance of
#
# certain ca<span class="_ _0"></span>t<span class="_ _0"></span>egories
# in the business con<span class="_ _0"></span>te<span
# class="_ _1"></span>xt.
#
# <img
# src="data:image/png;base64,..."
# class="bi x0 y0 w1 h1" />
#
# ![](data:image/png;base64,...)
